# %%
# %load_ext autoreload
# %autoreload 2

from sklearn.model_selection import ShuffleSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.cross_decomposition import PLSRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import ElasticNet
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor


from nirs4all.operators.transformations import Gaussian, SavitzkyGolay, StandardNormalVariate, Haar, MultiplicativeScatterCorrection
from nirs4all.operators.models.cirad_tf import nicon, customizable_nicon
from nirs4all.pipeline.config import PipelineConfigs
from nirs4all.dataset.dataset_config import DatasetConfigs
from nirs4all.pipeline.runner import PipelineRunner
from sklearn.ensemble import GradientBoostingRegressor

pipeline = [
    MinMaxScaler(feature_range=(0.1, 0.8)),
    {"feature_augmentation": [
        MultiplicativeScatterCorrection, Gaussian, StandardNormalVariate, SavitzkyGolay, Haar,
        [MultiplicativeScatterCorrection, Gaussian],
        [MultiplicativeScatterCorrection, StandardNormalVariate],
        [MultiplicativeScatterCorrection, SavitzkyGolay],
        [MultiplicativeScatterCorrection, Haar],
    ]},
    ShuffleSplit(n_splits=3),
    {"y_processing": MinMaxScaler},
    {"model": PLSRegression(15)},
    {"model": ElasticNet()},
    {"model": GradientBoostingRegressor(n_estimators=100)},
    {"model": nicon,
     "train_params": {
                # Final training parameters
                "epochs": 500,
                "patience": 50,
                "batch_size": 500,
                # "cyclic_lr": True,
                # "step_size": 20,
                "lr": 0.001,
                "verbose": 0  # 0=silent, 1=progress bar, 2=one line per epoch
            },
    },
]

# create pipeline config
config = PipelineConfigs(pipeline)

path = ['../../sample_data/regression', '../../sample_data/regression', '../../sample_data/regression']
dataset_config_obj = DatasetConfigs(path)

# Runner setup with spinner enabled (default is True, but let's be explicit)
runner = PipelineRunner(save_files=False, show_spinner=True, verbose=0)
print("🔄 Running pipeline with spinner enabled - watch for loading animations during model training!")
predictions, results = runner.run(config, dataset_config_obj)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ✅ Loaded pipeline(s) with 1 configuration(s).
# 🔄 Running pipeline with spinner enabled - watch for loading animations during model training!
# ========================================================================================================================================================================================================
# 📥 Loaded 774 predictions from results\regression\regression_predictions.json
# ========================================================================================================================================================================================================
# 🚀 Starting pipeline config_d701e255 on dataset regression
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 🔷 Step 1: {'class': 'sklearn.preprocessing._data.MinMaxScaler', 'params': {'feature_range': [0.1, 0.8]}, '_runtime_instance': MinMaxScaler(feature_range=(0.1, 0.8))}
# 🔹 Executing controller TransformerMixinController with operator MinMaxScaler
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Update: 📊 Dataset: regression
# Features (samples=189, sources=1):
# - Source 0: (189, 1, 2151), processings=['raw_MinMaxScaler_1'], min=0.1, max=0.89, mean=0.661, var=0.016)
# Targets: (samples=189, targets=1, processings=['numeric'])
# - numeric: min=1.33, max=128.31, mean=30.779
# Indexes:
# - "train", ['raw_MinMaxScaler_1']: 130 samples
# - "test", ['raw_MinMaxScaler_1']: 59 samples
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 🔷 Step 2: {'feature_augmentation': ['nirs4all.operators.transformations.nirs.MultiplicativeScatterCorrection', 'nirs4all.operators.transformations.signal.Gaussian', 'sklearn.preprocessing._data.StandardScaler', 'nirs4all.operators.transformations.nirs.SavitzkyGolay', 'nirs4all.operators.transformations.nirs.Haar', ['nirs4all.operators.transformations.nirs.MultiplicativeScatterCorrection', 'nirs4all.operators.transformations.signal.Gaussian'], ['nirs4all.operators.transformations.nirs.MultiplicativeScatterCorrection', 'sklearn.preprocessing._data.StandardScaler'], ['nirs4all.operators.transformations.nirs.MultiplicativeScatterCorrection', 'nirs4all.operators.transformations.nirs.SavitzkyGolay'], ['nirs4all.operators.transformations.nirs.MultiplicativeScatterCorrection', 'nirs4all.operators.transformations.nirs.Haar']]}
# 🔹 Executing controller FeatureAugmentationController without operator
# 🔄 FeatureAugmentation ⠋   ▶ Sub-step 2.1: nirs4all.operators.transformations.nirs.MultiplicativeScatterCorrection
# 🔹 Executing controller TransformerMixinController with operator MultiplicativeScatterCorrection
#    ▶ Sub-step 2.2: nirs4all.operators.transformations.signal.Gaussian
# 🔹 Executing controller TransformerMixinController with operator Gaussian
#    ▶ Sub-step 2.3: sklearn.preprocessing._data.StandardScaler
# 🔹 Executing controller TransformerMixinController with operator StandardScaler
# 🔄 FeatureAugmentation ⠼             ⠋   ▶ Sub-step 2.4: nirs4all.operators.transformations.nirs.SavitzkyGolay
# 🔹 Executing controller TransformerMixinController with operator SavitzkyGolay
# 🔄 FeatureAugmentation ⠴            ⠋   ▶ Sub-step 2.5: nirs4all.operators.transformations.nirs.Haar
# 🔹 Executing controller TransformerMixinController with operator Haar
#    ▶ Sub-step 2.6: ['nirs4all.operators.transformations.nirs.MultiplicativeScatterCorrection', 'nirs4all.operators.transformations.signal.Gaussian']
#    ▶ Sub-step 2.7: nirs4all.operators.transformations.nirs.MultiplicativeScatterCorrection
# 🔹 Executing controller TransformerMixinController with operator MultiplicativeScatterCorrection
#    ▶ Sub-step 2.8: nirs4all.operators.transformations.signal.Gaussian
# 🔹 Executing controller TransformerMixinController with operator Gaussian
#    ▶ Sub-step 2.0: ['nirs4all.operators.transformations.nirs.MultiplicativeScatterCorrection', 'sklearn.preprocessing._data.StandardScaler']
#    ▶ Sub-step 2.1: nirs4all.operators.transformations.nirs.MultiplicativeScatterCorrection
# 🔹 Executing controller TransformerMixinController with operator MultiplicativeScatterCorrection
#    ▶ Sub-step 2.2: sklearn.preprocessing._data.StandardScaler
# 🔹 Executing controller TransformerMixinController with operator StandardScaler
#    ▶ Sub-step 2.0: ['nirs4all.operators.transformations.nirs.MultiplicativeScatterCorrection', 'nirs4all.operators.transformations.nirs.SavitzkyGolay']
#    ▶ Sub-step 2.1: nirs4all.operators.transformations.nirs.MultiplicativeScatterCorrection
# 🔹 Executing controller TransformerMixinController with operator MultiplicativeScatterCorrection
#    ▶ Sub-step 2.2: nirs4all.operators.transformations.nirs.SavitzkyGolay
# 🔹 Executing controller TransformerMixinController with operator SavitzkyGolay
#    ▶ Sub-step 2.0: ['nirs4all.operators.transformations.nirs.MultiplicativeScatterCorrection', 'nirs4all.operators.transformations.nirs.Haar']
#    ▶ Sub-step 2.1: nirs4all.operators.transformations.nirs.MultiplicativeScatterCorrection
# 🔹 Executing controller TransformerMixinController with operator MultiplicativeScatterCorrection
#    ▶ Sub-step 2.2: nirs4all.operators.transformations.nirs.Haar
# 🔹 Executing controller TransformerMixinController with operator Haar
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Update: 📊 Dataset: regression
# Features (samples=189, sources=1):
# - Source 0: (189, 1, 2151), processings=['raw_MinMaxScaler_1_MultiplicativeScatterCorrection_2'], min=-0.985, max=0.276, mean=0.008, var=0.013)
# Targets: (samples=189, targets=1, processings=['numeric'])
# - numeric: min=1.33, max=128.31, mean=30.779
# Indexes:
# - "train", ['raw_MinMaxScaler_1_MultiplicativeScatterCorrection_2']: 130 samples
# - "test", ['raw_MinMaxScaler_1_MultiplicativeScatterCorrection_2']: 59 samples
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 🔷 Step 3: {'class': 'sklearn.model_selection._split.ShuffleSplit', 'params': {'n_splits': 3}, '_runtime_instance': ShuffleSplit(n_splits=3, random_state=None, test_size=None, train_size=None)}
# 🔹 Executing controller CrossValidatorController with operator ShuffleSplit
# Generated 3 folds.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Update: 📊 Dataset: regression
# Features (samples=189, sources=1):
# - Source 0: (189, 1, 2151), processings=['raw_MinMaxScaler_1_MultiplicativeScatterCorrection_2'], min=-0.985, max=0.276, mean=0.008, var=0.013)
# Targets: (samples=189, targets=1, processings=['numeric'])
# - numeric: min=1.33, max=128.31, mean=30.779
# Indexes:
# - "train", ['raw_MinMaxScaler_1_MultiplicativeScatterCorrection_2']: 130 samples
# - "test", ['raw_MinMaxScaler_1_MultiplicativeScatterCorrection_2']: 59 samples
# Folds: [(117, 13), (117, 13), (117, 13)]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 🔷 Step 4: {'y_processing': {'class': 'sklearn.preprocessing._data.MinMaxScaler'}}
# 🔹 Executing controller YTransformerMixinController with operator MinMaxScaler
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Update: 📊 Dataset: regression
# Features (samples=189, sources=1):
# - Source 0: (189, 1, 2151), processings=['raw_MinMaxScaler_1_MultiplicativeScatterCorrection_2'], min=-0.985, max=0.276, mean=0.008, var=0.013)
# Targets: (samples=189, targets=1, processings=['numeric', 'numeric_MinMaxScaler3'])
# - numeric: min=1.33, max=128.31, mean=30.779
# - numeric_MinMaxScaler3: min=-0.006, max=1.0, mean=0.228
# Indexes:
# - "train", ['raw_MinMaxScaler_1_MultiplicativeScatterCorrection_2']: 130 samples
# - "test", ['raw_MinMaxScaler_1_MultiplicativeScatterCorrection_2']: 59 samples
# Folds: [(117, 13), (117, 13), (117, 13)]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 🔷 Step 5: {'model': {'class': 'sklearn.cross_decomposition._pls.PLSRegression', 'params': {'n_components': 15}, '_runtime_instance': PLSRegression(n_components=15)}}
# 🔹 Executing controller SklearnModelController with operator PLSRegression
# 🔄 SklearnModel (PLSRegression) ⠋✅ PLSRegression_4 - test: mse=0.0118↓ (mae: 0.0991)
# 💾 Saved 1 predictions to results\regression\config_d701e255\regression_predictions.json
# ✅ PLSRegression_7 - test: mse=0.0065↓ (mae: 0.0690)
# 💾 Saved 2 predictions to results\regression\config_d701e255\regression_predictions.json
# 🔄 SklearnModel (PLSRegression) ⠙✅ PLSRegression_10 - test: mse=0.0127↓ (mae: 0.0812)
# 💾 Saved 3 predictions to results\regression\config_d701e255\regression_predictions.json
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 🔷 Step 6: {'model': {'class': 'sklearn.linear_model._coordinate_descent.ElasticNet', '_runtime_instance': ElasticNet()}}
# 🔹 Executing controller SklearnModelController with operator ElasticNet
# 🔄 SklearnModel (ElasticNet) ⠋✅ ElasticNet_13 - test: mse=0.0544↓ (mae: 0.1692)
# 💾 Saved 4 predictions to results\regression\config_d701e255\regression_predictions.json
# ✅ ElasticNet_16 - test: mse=0.0173↓ (mae: 0.1110)
# 💾 Saved 5 predictions to results\regression\config_d701e255\regression_predictions.json
# ✅ ElasticNet_19 - test: mse=0.0716↓ (mae: 0.1824)
# 💾 Saved 6 predictions to results\regression\config_d701e255\regression_predictions.json
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 🔷 Step 7: {'model': {'class': 'sklearn.ensemble._gb.GradientBoostingRegressor', '_runtime_instance': GradientBoostingRegressor()}}
# 🔹 Executing controller SklearnModelController with operator GradientBoostingRegressor
# 🔄 SklearnModel (GradientBoostingRegressor) ⠦✅ GradientBoostingRegressor_22 - test: mse=0.0354↓ (mae: 0.1595)
# 💾 Saved 7 predictions to results\regression\config_d701e255\regression_predictions.json
# 🔄 SklearnModel (GradientBoostingRegressor) ⠸✅ GradientBoostingRegressor_25 - test: mse=0.0215↓ (mae: 0.1096)
# 💾 Saved 8 predictions to results\regression\config_d701e255\regression_predictions.json
# 🔄 SklearnModel (GradientBoostingRegressor) ⠏✅ GradientBoostingRegressor_28 - test: mse=0.0756↓ (mae: 0.1917)
# 💾 Saved 9 predictions to results\regression\config_d701e255\regression_predictions.json
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 🔷 Step 8: {'model': {'function': 'nirs4all.operators.models.cirad_tf.nicon'}, 'train_params': {'epochs': 500, 'patience': 50, 'batch_size': 500, 'lr': 0.001, 'verbose': 0}}
# 🔹 Executing controller TensorFlowModelController without operator
# 🔄 TensorFlowModel ⠧✅ nicon_31 - test: mse=0.0496↓ (mae: 0.1832)
# 💾 Saved 10 predictions to results\regression\config_d701e255\regression_predictions.json
# 🔄 TensorFlowModel ⠇
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002F1C6AA0700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 🔄 TensorFlowModel ⠏✅ nicon_34 - test: mse=0.0217↓ (mae: 0.1240)
# 💾 Saved 11 predictions to results\regression\config_d701e255\regression_predictions.json
# 🔄 TensorFlowModel ⠏
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002F1B68F1990> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ✅ nicon_37 - test: mse=0.0543↓ (mae: 0.1732)
# 💾 Saved 12 predictions to results\regression\config_d701e255\regression_predictions.json
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 🏆 Best for config: fold (config_d701e255) - mse=104.0448↓
# ✅ Pipeline config_d701e255 completed successfully on dataset regression
# --------------------------------------------------------------------------------------------------------------------------------------------
# 🏆 Best from this run: fold (config_d701e255_PLSRegression_7_test) - mse=104.0448↓
# 💾 Saved 786 predictions to results\regression\regression_predictions.json
# ========================================================================================================================================================================================================
# 📥 Loaded 786 predictions from results\regression\regression_predictions.json
# ========================================================================================================================================================================================================
# 🚀 Starting pipeline config_d701e255 on dataset regression
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 🔷 Step 1: {'class': 'sklearn.preprocessing._data.MinMaxScaler', 'params': {'feature_range': [0.1, 0.8]}, '_runtime_instance': MinMaxScaler(feature_range=(0.1, 0.8))}
# 🔹 Executing controller TransformerMixinController with operator MinMaxScaler
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Update: 📊 Dataset: regression
# Features (samples=189, sources=1):
# - Source 0: (189, 1, 2151), processings=['raw_MinMaxScaler_1'], min=0.1, max=0.89, mean=0.661, var=0.016)
# Targets: (samples=189, targets=1, processings=['numeric'])
# - numeric: min=1.33, max=128.31, mean=30.779
# Indexes:
# - "train", ['raw_MinMaxScaler_1']: 130 samples
# - "test", ['raw_MinMaxScaler_1']: 59 samples
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 🔷 Step 2: {'feature_augmentation': ['nirs4all.operators.transformations.nirs.MultiplicativeScatterCorrection', 'nirs4all.operators.transformations.signal.Gaussian', 'sklearn.preprocessing._data.StandardScaler', 'nirs4all.operators.transformations.nirs.SavitzkyGolay', 'nirs4all.operators.transformations.nirs.Haar', ['nirs4all.operators.transformations.nirs.MultiplicativeScatterCorrection', 'nirs4all.operators.transformations.signal.Gaussian'], ['nirs4all.operators.transformations.nirs.MultiplicativeScatterCorrection', 'sklearn.preprocessing._data.StandardScaler'], ['nirs4all.operators.transformations.nirs.MultiplicativeScatterCorrection', 'nirs4all.operators.transformations.nirs.SavitzkyGolay'], ['nirs4all.operators.transformations.nirs.MultiplicativeScatterCorrection', 'nirs4all.operators.transformations.nirs.Haar']]}
# 🔹 Executing controller FeatureAugmentationController without operator
# 🔄 FeatureAugmentation ⠋   ▶ Sub-step 2.1: nirs4all.operators.transformations.nirs.MultiplicativeScatterCorrection
# 🔹 Executing controller TransformerMixinController with operator MultiplicativeScatterCorrection
#    ▶ Sub-step 2.2: nirs4all.operators.transformations.signal.Gaussian
# 🔹 Executing controller TransformerMixinController with operator Gaussian
#    ▶ Sub-step 2.3: sklearn.preprocessing._data.StandardScaler
# 🔹 Executing controller TransformerMixinController with operator StandardScaler
#    ▶ Sub-step 2.4: nirs4all.operators.transformations.nirs.SavitzkyGolay
# 🔹 Executing controller TransformerMixinController with operator SavitzkyGolay
# 🔄 FeatureAugmentation ⠴            ⠋   ▶ Sub-step 2.5: nirs4all.operators.transformations.nirs.Haar
# 🔹 Executing controller TransformerMixinController with operator Haar
#    ▶ Sub-step 2.6: ['nirs4all.operators.transformations.nirs.MultiplicativeScatterCorrection', 'nirs4all.operators.transformations.signal.Gaussian']
#    ▶ Sub-step 2.7: nirs4all.operators.transformations.nirs.MultiplicativeScatterCorrection
# 🔹 Executing controller TransformerMixinController with operator MultiplicativeScatterCorrection
# 🔄 FeatureAugmentation ⠧                              ⠋   ▶ Sub-step 2.8: nirs4all.operators.transformations.signal.Gaussian
# 🔹 Executing controller TransformerMixinController with operator Gaussian
# 🔄 FeatureAugmentation ⠇       ⠋   ▶ Sub-step 2.0: ['nirs4all.operators.transformations.nirs.MultiplicativeScatterCorrection', 'sklearn.preprocessing._data.StandardScaler']
#    ▶ Sub-step 2.1: nirs4all.operators.transformations.nirs.MultiplicativeScatterCorrection
# 🔹 Executing controller TransformerMixinController with operator MultiplicativeScatterCorrection
# 🔄 FeatureAugmentation ⠏                              ⠋   ▶ Sub-step 2.2: sklearn.preprocessing._data.StandardScaler
# 🔹 Executing controller TransformerMixinController with operator StandardScaler
#    ▶ Sub-step 2.0: ['nirs4all.operators.transformations.nirs.MultiplicativeScatterCorrection', 'nirs4all.operators.transformations.nirs.SavitzkyGolay']
#    ▶ Sub-step 2.1: nirs4all.operators.transformations.nirs.MultiplicativeScatterCorrection
# 🔹 Executing controller TransformerMixinController with operator MultiplicativeScatterCorrection
#    ▶ Sub-step 2.2: nirs4all.operators.transformations.nirs.SavitzkyGolay
# 🔹 Executing controller TransformerMixinController with operator SavitzkyGolay
#    ▶ Sub-step 2.0: ['nirs4all.operators.transformations.nirs.MultiplicativeScatterCorrection', 'nirs4all.operators.transformations.nirs.Haar']
#    ▶ Sub-step 2.1: nirs4all.operators.transformations.nirs.MultiplicativeScatterCorrection
# 🔹 Executing controller TransformerMixinController with operator MultiplicativeScatterCorrection
#    ▶ Sub-step 2.2: nirs4all.operators.transformations.nirs.Haar
# 🔹 Executing controller TransformerMixinController with operator Haar
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Update: 📊 Dataset: regression
# Features (samples=189, sources=1):
# - Source 0: (189, 1, 2151), processings=['raw_MinMaxScaler_1_MultiplicativeScatterCorrection_2'], min=-0.985, max=0.276, mean=0.008, var=0.013)
# Targets: (samples=189, targets=1, processings=['numeric'])
# - numeric: min=1.33, max=128.31, mean=30.779
# Indexes:
# - "train", ['raw_MinMaxScaler_1_MultiplicativeScatterCorrection_2']: 130 samples
# - "test", ['raw_MinMaxScaler_1_MultiplicativeScatterCorrection_2']: 59 samples
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 🔷 Step 3: {'class': 'sklearn.model_selection._split.ShuffleSplit', 'params': {'n_splits': 3}, '_runtime_instance': ShuffleSplit(n_splits=3, random_state=None, test_size=None, train_size=None)}
# 🔹 Executing controller CrossValidatorController with operator ShuffleSplit
# Generated 3 folds.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Update: 📊 Dataset: regression
# Features (samples=189, sources=1):
# - Source 0: (189, 1, 2151), processings=['raw_MinMaxScaler_1_MultiplicativeScatterCorrection_2'], min=-0.985, max=0.276, mean=0.008, var=0.013)
# Targets: (samples=189, targets=1, processings=['numeric'])
# - numeric: min=1.33, max=128.31, mean=30.779
# Indexes:
# - "train", ['raw_MinMaxScaler_1_MultiplicativeScatterCorrection_2']: 130 samples
# - "test", ['raw_MinMaxScaler_1_MultiplicativeScatterCorrection_2']: 59 samples
# Folds: [(117, 13), (117, 13), (117, 13)]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 🔷 Step 4: {'y_processing': {'class': 'sklearn.preprocessing._data.MinMaxScaler'}}
# 🔹 Executing controller YTransformerMixinController with operator MinMaxScaler
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Update: 📊 Dataset: regression
# Features (samples=189, sources=1):
# - Source 0: (189, 1, 2151), processings=['raw_MinMaxScaler_1_MultiplicativeScatterCorrection_2'], min=-0.985, max=0.276, mean=0.008, var=0.013)
# Targets: (samples=189, targets=1, processings=['numeric', 'numeric_MinMaxScaler3'])
# - numeric: min=1.33, max=128.31, mean=30.779
# - numeric_MinMaxScaler3: min=-0.006, max=1.0, mean=0.228
# Indexes:
# - "train", ['raw_MinMaxScaler_1_MultiplicativeScatterCorrection_2']: 130 samples
# - "test", ['raw_MinMaxScaler_1_MultiplicativeScatterCorrection_2']: 59 samples
# Folds: [(117, 13), (117, 13), (117, 13)]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 🔷 Step 5: {'model': {'class': 'sklearn.cross_decomposition._pls.PLSRegression', 'params': {'n_components': 15}, '_runtime_instance': PLSRegression(n_components=15)}}
# 🔹 Executing controller SklearnModelController with operator PLSRegression
# 🔄 SklearnModel (PLSRegression) ⠋✅ PLSRegression_4 - test: mse=0.0100↓ (mae: 0.0834)
# 💾 Saved 1 predictions to results\regression\config_d701e255\regression_predictions.json
# ✅ PLSRegression_7 - test: mse=0.0264↓ (mae: 0.1208)
# 💾 Saved 2 predictions to results\regression\config_d701e255\regression_predictions.json
# ✅ PLSRegression_10 - test: mse=0.0087↓ (mae: 0.0682)
# 💾 Saved 3 predictions to results\regression\config_d701e255\regression_predictions.json
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 🔷 Step 6: {'model': {'class': 'sklearn.linear_model._coordinate_descent.ElasticNet', '_runtime_instance': ElasticNet()}}
# 🔹 Executing controller SklearnModelController with operator ElasticNet
# 🔄 SklearnModel (ElasticNet) ⠋✅ ElasticNet_13 - test: mse=0.0228↓ (mae: 0.1226)
# 💾 Saved 4 predictions to results\regression\config_d701e255\regression_predictions.json
# ✅ ElasticNet_16 - test: mse=0.1152↓ (mae: 0.2348)
# 💾 Saved 5 predictions to results\regression\config_d701e255\regression_predictions.json
# ✅ ElasticNet_19 - test: mse=0.0182↓ (mae: 0.1079)
# 💾 Saved 6 predictions to results\regression\config_d701e255\regression_predictions.json
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 🔷 Step 7: {'model': {'class': 'sklearn.ensemble._gb.GradientBoostingRegressor', '_runtime_instance': GradientBoostingRegressor()}}
# 🔹 Executing controller SklearnModelController with operator GradientBoostingRegressor
# 🔄 SklearnModel (GradientBoostingRegressor) ⠧✅ GradientBoostingRegressor_22 - test: mse=0.0202↓ (mae: 0.1240)
# 💾 Saved 7 predictions to results\regression\config_d701e255\regression_predictions.json
# 🔄 SklearnModel (GradientBoostingRegressor) ⠦✅ GradientBoostingRegressor_25 - test: mse=0.1004↓ (mae: 0.2171)
# 💾 Saved 8 predictions to results\regression\config_d701e255\regression_predictions.json
# 🔄 SklearnModel (GradientBoostingRegressor) ⠹✅ GradientBoostingRegressor_28 - test: mse=0.0288↓ (mae: 0.1277)
# 💾 Saved 9 predictions to results\regression\config_d701e255\regression_predictions.json
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 🔷 Step 8: {'model': {'function': 'nirs4all.operators.models.cirad_tf.nicon'}, 'train_params': {'epochs': 500, 'patience': 50, 'batch_size': 500, 'lr': 0.001, 'verbose': 0, 'loss': 'mse', 'metrics': ['mae', 'mse']}}
# 🔹 Executing controller TensorFlowModelController without operator
# 🔄 TensorFlowModel ⠼✅ nicon_31 - test: mse=0.0173↓ (mae: 0.1132)
# 💾 Saved 10 predictions to results\regression\config_d701e255\regression_predictions.json
# 🔄 TensorFlowModel ⠸

# %%
import matplotlib.pyplot as plt
import numpy as np
from nirs4all.dataset.prediction_visualizer import PredictionVisualizer

# global_predictions, run_predictions = results[0]
visualizer = PredictionVisualizer(predictions, dataset_name_override="dataset")

best = visualizer.get_best_models_by_type()
for model_type, model_info in best.items():
    print(f"Best {model_info['base_model']}: {model_type} (partition: {model_info['partition']}) - RMSE: {model_info['metrics']['rmse']:.6f}, R²: {model_info['metrics']['r2']:.6f}, MAE: {model_info['metrics']['mae']:.6f}")
fig = visualizer.plot_best_models_predictions(metric='rmse')
fig = visualizer.plot_models_performance_bars(metric='rmse')
# Out:
# Best PLSRegression: PLSRegression (partition: test_fold_2) - RMSE: 14.890420, R²: 0.583430, MAE: 12.167355
# Best ElasticNet: ElasticNet (partition: test_fold_1) - RMSE: 18.679089, R²: -0.000107, MAE: 14.911544
# Best GradientBoostingRegressor: GradientBoostingRegressor (partition: test_fold_2) - RMSE: 23.172903, R²: -0.008869, MAE: 18.007125
# Best nicon: nicon (partition: test_fold_2) - RMSE: 18.726370, R²: 0.341158, MAE: 14.861174
